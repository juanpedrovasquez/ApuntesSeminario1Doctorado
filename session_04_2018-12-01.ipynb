# %% [markdown]
# <img src="http://universidadcucii.mx/img/demos/law-firm/logo.png" width="200">
#
# # Universidad CUCII
# ## Doctorado en innovación y administración educativa
# ### Seminario de Investigación 1
#
# #### Sesión 04 (2018-12-01)

# %%
# NO HAGAN CASO DE ESTA CELDA DE CÓDIGO
# ES SÓLO PARA FORMATO DE ESTE DOCUMENTO
library(repr)
ancho=8
options(repr.plot.width=ancho, repr.plot.height=round(ancho/1.618034))

# %% [markdown]
# ##### 1. Diferencia entre poblacion y muestra

# %%
muestra <- rnorm(n = 30, mean = 140, sd = 0.5)
summary(muestra)
hist(muestra, labels = TRUE, probability = T, 
     main="muestra de 30 indivs.", 
     ylab = "Densidad", border=F, col="lightgray")
lines(density(muestra),lwd=2,col="red")
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   138.8   139.7   140.0   140.0   140.3   140.7
# Plot with title “muestra de 30 indivs.”

# %%
poblacion <- rnorm(n = 3e7, mean = 140, sd = 0.5)
summary(poblacion)
hist(poblacion, labels = TRUE, probability = T, 
     main="poblacion de 30 millones indivs.", 
     ylab = "Densidad", border=F, col="lightgray")
lines(density(poblacion),lwd=2,col="red")
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   137.0   139.7   140.0   140.0   140.3   142.7
# Plot with title “poblacion de 30 millones indivs.”

# %%
#REVISE LA DIFERENCIA ENTRE LOS VALORES DE LA MUESTRA DE 30 INDIVS
#Y LA POBLACION DE 30 MILLONES, ESE ES EL PODER DE LA ESTADÌSTICA
summary(muestra)
summary(poblacion)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   138.8   139.7   140.0   140.0   140.3   140.7
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   137.0   139.7   140.0   140.0   140.3   142.7

# %% [markdown]
# <img src="http://4.bp.blogspot.com/-WDkWDxHmadM/Tq19TE4opII/AAAAAAAAJh4/VGG9Ek3Mn7s/s1600/amlo-caricatura-992981.jpeg" width="200">

# %% [markdown]
# POR SER DEL INTERÈS GENERAL, LA CLASE LLEGÒ HASTA AQUÌ.

# %% [markdown]
# ##### 2. Algunas otras distribuciones de probabilidad

# %% [markdown]
# ##### 3. Aplicaciones básicas de probabilidad

# %% [markdown]
# ##### ¿Qué probabilidad tienen los alumnos de sacar más de 5 y menos de 8?

# %% [markdown]
# ##### ¿Qué probabilidad tienen los alumnos de sacar exactamente 7?

# %% [markdown]
# ##### ¿Qué probabilidad tienen los alumnos de sacar al menos 8?
